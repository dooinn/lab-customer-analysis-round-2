# %%
import pandas as pd

# %%
df = pd.read_csv('/Users/dooinnkim/ironhack_da_may_2023/lab-customer-analysis-round-2/files_for_lab/csv_files/marketing_customer_analysis.csv')

# %%
df.head()
# Out:
#    Unnamed: 0 Customer       State  Customer Lifetime Value Response  \
# 0           0  DK49336     Arizona              4809.216960       No
# 1           1  KX64629  California              2228.525238       No
# 2           2  LZ68649  Washington             14947.917300       No
# 3           3  XL78013      Oregon             22332.439460      Yes
# 4           4  QA50777      Oregon              9025.067525       No
#
#    Coverage Education Effective To Date EmploymentStatus Gender  ...  \
# 0     Basic   College           2/18/11         Employed      M  ...
# 1     Basic   College           1/18/11       Unemployed      F  ...
# 2     Basic  Bachelor           2/10/11         Employed      M  ...
# 3  Extended   College           1/11/11         Employed      M  ...
# 4   Premium  Bachelor           1/17/11    Medical Leave      F  ...
#
#    Number of Open Complaints Number of Policies     Policy Type        Policy  \
# ...

# %% [markdown]
# ## 1. Show the dataframe shape.

# %%
df.shape
# Out:
# (10910, 26)

# %% [markdown]
# ## 2. Standardize header names.

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Customer', 'State', 'Customer Lifetime Value',
#        'Response', 'Coverage', 'Education', 'Effective To Date',
#        'EmploymentStatus', 'Gender', 'Income', 'Location Code',
#        'Marital Status', 'Monthly Premium Auto', 'Months Since Last Claim',
#        'Months Since Policy Inception', 'Number of Open Complaints',
#        'Number of Policies', 'Policy Type', 'Policy', 'Renew Offer Type',
#        'Sales Channel', 'Total Claim Amount', 'Vehicle Class', 'Vehicle Size',
#        'Vehicle Type'],
#       dtype='object')

# %%
df.columns = [column.lower().replace(' ', '_') for column in df.columns]

# %%
df.columns
# Out:
# Index(['unnamed:_0', 'customer', 'state', 'customer_lifetime_value',
#        'response', 'coverage', 'education', 'effective_to_date',
#        'employmentstatus', 'gender', 'income', 'location_code',
#        'marital_status', 'monthly_premium_auto', 'months_since_last_claim',
#        'months_since_policy_inception', 'number_of_open_complaints',
#        'number_of_policies', 'policy_type', 'policy', 'renew_offer_type',
#        'sales_channel', 'total_claim_amount', 'vehicle_class', 'vehicle_size',
#        'vehicle_type'],
#       dtype='object')

# %% [markdown]
# ## 3. Which columns are numerical?
# ## 4. Which columns are categorical?
#
# - Numerical : all columns with data types int64 and float64
# - Categorical: all columns with object

# %%
df.dtypes
# Out:
# unnamed:_0                         int64
# customer                          object
# state                             object
# customer_lifetime_value          float64
# response                          object
# coverage                          object
# education                         object
# effective_to_date                 object
# employmentstatus                  object
# gender                            object
# income                             int64
# location_code                     object
# marital_status                    object
# monthly_premium_auto               int64
# months_since_last_claim          float64
# months_since_policy_inception      int64
# number_of_open_complaints        float64
# number_of_policies                 int64
# policy_type                       object
# policy                            object
# renew_offer_type                  object
# sales_channel                     object
# total_claim_amount               float64
# ...

# %% [markdown]
# ## 5. Check and deal with NaN values.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10910 entries, 0 to 10909
# Data columns (total 26 columns):
# unnamed:_0                       10910 non-null int64
# customer                         10910 non-null object
# state                            10279 non-null object
# customer_lifetime_value          10910 non-null float64
# response                         10279 non-null object
# coverage                         10910 non-null object
# education                        10910 non-null object
# effective_to_date                10910 non-null object
# employmentstatus                 10910 non-null object
# gender                           10910 non-null object
# income                           10910 non-null int64
# location_code                    10910 non-null object
# marital_status                   10910 non-null object
# monthly_premium_auto             10910 non-null int64
# months_since_last_claim          10277 non-null float64
# ...

# %%
# Get the numerical columns
numerical_columns = df.select_dtypes(include=['int64', 'float64']).columns

# Get the categorical columns
categorical_columns = df.select_dtypes(include=['object', 'category']).columns

print("Numerical columns:", list(numerical_columns))
print("Categorical columns:", list(categorical_columns))
# Out:
# Numerical columns: ['unnamed:_0', 'customer_lifetime_value', 'income', 'monthly_premium_auto', 'months_since_last_claim', 'months_since_policy_inception', 'number_of_open_complaints', 'number_of_policies', 'total_claim_amount']
# Categorical columns: ['customer', 'state', 'response', 'coverage', 'education', 'effective_to_date', 'employmentstatus', 'gender', 'location_code', 'marital_status', 'policy_type', 'policy', 'renew_offer_type', 'sales_channel', 'vehicle_class', 'vehicle_size', 'vehicle_type']

# %%
df.isna().sum()
# Out:
# unnamed:_0                          0
# customer                            0
# state                             631
# customer_lifetime_value             0
# response                          631
# coverage                            0
# education                           0
# effective_to_date                   0
# employmentstatus                    0
# gender                              0
# income                              0
# location_code                       0
# marital_status                      0
# monthly_premium_auto                0
# months_since_last_claim           633
# months_since_policy_inception       0
# number_of_open_complaints         633
# number_of_policies                  0
# policy_type                         0
# policy                              0
# renew_offer_type                    0
# sales_channel                       0
# total_claim_amount                  0
# vehicle_class                     622
# vehicle_size                      622
# ...

# %%
display(df['state'].value_counts())
display(df['response'].value_counts())
display(df['vehicle_class'].value_counts())
display(df['vehicle_size'].value_counts())
display(df['vehicle_type'].value_counts())
# Out:
# California    3552
# Oregon        2909
# Arizona       1937
# Nevada         993
# Washington     888
# Name: state, dtype: int64
# No     8813
# Yes    1466
# Name: response, dtype: int64
# Four-Door Car    5212
# Two-Door Car     2118
# SUV              2012
# Sports Car        550
# Luxury SUV        208
# Luxury Car        188
# Name: vehicle_class, dtype: int64
# Medsize    7251
# Small      1966
# Large      1071
# Name: vehicle_size, dtype: int64
# A    5428
# Name: vehicle_type, dtype: int64

# %%
df['state'] = df['state'].fillna('Other')
df['response'] = df['response'].fillna('Other')
df['vehicle_class'] = df['vehicle_class'].fillna('Other')
df['vehicle_size'] = df['vehicle_size'].fillna('Other')
df['vehicle_type'] = df['vehicle_type'].fillna('Other')

# %%
claim_median = df["months_since_last_claim"].median()
df["months_since_last_claim"] = df["months_since_last_claim"].fillna(claim_median)

complain_median = df["number_of_open_complaints"].median()
df["number_of_open_complaints"] = df["number_of_open_complaints"].fillna(complain_median)

# %%
df.isna().sum()
# Out:
# unnamed:_0                       0
# customer                         0
# state                            0
# customer_lifetime_value          0
# response                         0
# coverage                         0
# education                        0
# effective_to_date                0
# employmentstatus                 0
# gender                           0
# income                           0
# location_code                    0
# marital_status                   0
# monthly_premium_auto             0
# months_since_last_claim          0
# months_since_policy_inception    0
# number_of_open_complaints        0
# number_of_policies               0
# policy_type                      0
# policy                           0
# renew_offer_type                 0
# sales_channel                    0
# total_claim_amount               0
# vehicle_class                    0
# vehicle_size                     0
# vehicle_type                     0
# dtype: int64

# %% [markdown]
# ## 6. Datetime format - Extract the months from the dataset and store in a separate column.
#
# Then filter the data to show only the information for the first quarter , ie. January, February and March. Hint: If data from March does not exist, consider only January and February.

# %%
df['effective_to_date'] = pd.to_datetime(df['effective_to_date'])
df['effective_to_date']
# Out:
# 0       2011-02-18
# 1       2011-01-18
# 2       2011-02-10
# 3       2011-01-11
# 4       2011-01-17
#            ...
# 10905   2011-01-19
# 10906   2011-01-06
# 10907   2011-02-06
# 10908   2011-02-13
# 10909   2011-01-08
# Name: effective_to_date, Length: 10910, dtype: datetime64[ns]

# %%
df['month']=df['effective_to_date'].dt.month

# %%
df['month'].value_counts()
# Out:
# 1    5818
# 2    5092
# Name: month, dtype: int64

# %%
cond = (df['month'] == 1) | (df['month'] == 2) | (df['month'] == 3)
df[cond].sort_values("month", ascending=False)
# Out:
#        unnamed:_0 customer       state  customer_lifetime_value response  \
# 0               0  DK49336     Arizona              4809.216960       No
# 4338         4338  MW98508      Oregon              2889.087654       No
# 4350         4350  CN30964  California              6685.797205       No
# 8576         8576  QZ58370      Nevada             11820.109800       No
# 4347         4347  ZX50209  California             10960.936670       No
# ...           ...      ...         ...                      ...      ...
# 4694         4694  NL93182      Nevada              2549.450038       No
# 4693         4693  IZ37104  California              2267.604038       No
# 4692         4692  HH69970  California              6282.082435       No
# 4691         4691  YD80815     Arizona              7148.331333       No
# 10909       10909  IV32877       Other              6857.519928    Other
#
#        coverage education effective_to_date employmentstatus gender  ...  \
# ...

# %% [markdown]
# ## 7. BONUS: Put all the previously mentioned data transformations into a function.

# %%
def standard_header(x):
    return x.lower().replace(' ', '_')

df.columns = [standard_header(c) for c in df.columns]

# %%
def first_quarter(x):
    return (x['month'] == 1) | (x['month'] == 2) | (x['month'] == 3)


df[df.apply(first_quarter, axis=1)]
# Out:
#        unnamed:_0 customer       state  customer_lifetime_value response  \
# 0               0  DK49336     Arizona              4809.216960       No
# 1               1  KX64629  California              2228.525238       No
# 2               2  LZ68649  Washington             14947.917300       No
# 3               3  XL78013      Oregon             22332.439460      Yes
# 4               4  QA50777      Oregon              9025.067525       No
# ...           ...      ...         ...                      ...      ...
# 10905       10905  FE99816      Nevada             15563.369440       No
# 10906       10906  KX53892      Oregon              5259.444853       No
# 10907       10907  TL39050     Arizona             23893.304100       No
# 10908       10908  WA60547  California             11971.977650       No
# 10909       10909  IV32877       Other              6857.519928    Other
#
#        coverage education effective_to_date employmentstatus gender  ...  \
# ...
